# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
# import umap
import json
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
import pickle
import re

sns.set()

# %% [markdown]
# ### Using Yummy Data to Explore Food in Vector Space!
#
# My friend and I had a funny question (in the days before ChatGPT existed): if we let various NLP models cook, what recipes would they make?
# We started off with an EDA to look at what recipes look like if we look at it from a vectorized perspective - the results surprised us!
#
# At the time (early in my university career), I was just starting to learn NLP techniques, so we elected to process our words

# %%
DATA_PATH = "./data/recipes_raw_nosource_fn.json"

# %%
data = pd.read_json(DATA_PATH)
data = data.drop(['picture_link', 'title'])
data = data.dropna(axis=1)

# %%
data
# Out:
#                                 p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  \
# instructions  Toss ingredients lightly and spoon into a butt...
# ingredients   [1/2 cup celery, finely chopped, 1 small green...
#
#                                 S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  \
# instructions  Watch how to make this recipe.\nSprinkle the s...
# ingredients   [2 pounds skirt steak, cut into 1/2-inch dice,...
#
#                                 o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK  \
# instructions  In a large saucepan, let the beans soak in eno...
# ingredients   [1 1/2 cups dried black beans, picked over and...
#
#                                 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK  \
# instructions  Watch how to make this recipe.\nPreheat the ov...
# ingredients   [1 1/4 pounds ground chuck, One 15-ounce can t...
#
#                                 kRBQSWtqYWqtkb34FGeenBSbC32gIdO  \
# instructions  Special equipment: sushi mat\nCook the brown r...
# ingredients   [1 cup rice, brown, medium-grain, cooked, 1/2-...
#
#                                 PmoGGX9RC5zbMJXtZH1SKzWKLFX4Aii  \
# instructions  Heat a large nonstick skillet over medium-high...
# ingredients   [1 tablespoon extra-virgin olive oil, 2 baby I...
#
#                                 g2RYP1spIUlAYsytDMsdfLNQEOnLUrO  \
# instructions  Sprinkle the saffron into 1/4 cup hot water; l...
# ingredients   [1/2 teaspoon lightly crumbled saffron threads...
#
#                                 94NWE4F4C5NzgH0zYqSdmPM/G55BjKO  \
# instructions  If using top-sliced buns, spread softened butt...
# ingredients   [4 top--sliced hot-dog buns (or fashion your o...
#
#                                 HdIbPB/8cgk17hAzbc2jUN4VBn//QKS  \
# instructions  Cut around the stems of the peppers (reserving...
# ingredients   [6 green or red bell peppers, 1/2 cup olive oi...
#
#                                 mC7Nb4F2S.DMCjZ39kzS/ak9GqEp4iO  ...  \
# instructions  Preheat the oven to 450 degrees F. Put the cau...  ...
# ingredients   [1 medium head cauliflower (about 2 pounds), c...  ...
#
#                                 CUZuiIs2F5A4u4EzEXB/yHN38So5CRy  \
# instructions  Fill a glass or cocktail shaker with some ice....
# ingredients   [Ice, 1 slice jalapeno, seeded 1 by 1/4-inch p...
#
#                                 08JThnwO3qzkhSKVuef6Ehg.HVPXt7C  \
# instructions  Watch how to make this recipe.\nHeat a heavy m...
# ingredients   [1/4 cup butter, 1/3 cup sugar, 1 teaspoon gro...
#
#                                 0jaoQnb1iG0bnScGJOt/zmAl6lsOh6y  \
# instructions  Preheat the oven to 250 degrees F\nIn a small ...
# ingredients   [2 cups coconut milk, 1 short stalk lemon gras...
#
#                                 6Qp4fKIuJAkrukUvmccA8qWrezzLwFq  \
# instructions  Bring a small saucepan of water to a boil. Sep...
# ingredients   [2 large heads garlic, 1 cut-up chicken, about...
#
#                                 xwEq9YYRt37I/LTqQUWvAi1uSusxhDm  \
# instructions  Grease 8 cream horn metal cones. Cut the puff ...
# ingredients   [1 sheet frozen puff pastry, thawed, 1 egg, 1 ...
#
#                                 4bfMWxlbKhx/McJq/89k0SBdw.VvAzW  \
# instructions  Watch how to make this recipe.\nPreheat a gril...
# ingredients   [4 ears fresh corn, 2 heads Belgian endive, 2 ...
#
#                                 T8lWBA1fcVdjxhMSWuoAbGoy5Lj.A8m  \
# instructions  Preheat the broiler. Cut the tomatoes in 1/2 c...
# ingredients   [4 large plum tomatoes, Salt and sugar, 1 1/2 ...
#
#                                 f/coffo2TMs2J2gq5nTOUIqH2TRAkui  \
# instructions  Heat the oil and butter in a large skillet ove...
# ingredients   [3 tablespoons olive oil, 2 tablespoons unsalt...
#
#                                 q3aDJc4zoEF5QT4e7Mn.ieQwV.DyHwS  \
# instructions  Preheat oven to 350 degrees. On the top half o...
# ingredients   [8 ounces butter, 8 ounces bittersweet chocola...
#
#                                 7cXA77UpdDtIfBug2v6lEVIuV3Zcvhm
# instructions  Watch how to make this recipe.\nIn a medium sa...
# ingredients   [3 (10.5-ounce) cans restaurant-style condense...
#
# [2 rows x 59628 columns]

# %% [markdown]
# And here are the ingredients for one such recipe. Note the numbers and measurements, which we will remove to simplify our EDA.

# %%
data.loc['ingredients'][0]
# Out:
# C:\Users\sayan\AppData\Local\Temp\ipykernel_9360\3221995973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.loc['ingredients'][0]
# ['1/2 cup celery, finely chopped',
#  '1 small green pepper finely chopped',
#  '1/2 cup finely sliced green onions',
#  '1/4 cup chopped parsley',
#  '1 pound crabmeat',
#  '1 1/4 cups coarsely crushed cracker crumbs',
#  '1/2 teaspoon salt',
#  '3/4 teaspoons dry mustard',
#  'Dash hot sauce',
#  '1/4 cup heavy cream',
#  '1/2 cup melted butter']

# %% [markdown]
# Removing measurements:

# %%
punctuation = r"""!"#$%&*+,-.:;<=>?@[\]^_`{|}~()"""
punc_re = re.compile("[%s]" % punctuation)

numbers = r"1234567890/"
num_re = re.compile("[%s]" % numbers)

measure_re = re.compile("(cup.)|(tablespoon.)|(teaspoon.)|(tbsp.)|(tsp.)|" \
                        "(pound.)|(lb.)|(gram.)|(ounce.)|(slice.)|(can.)|(head.)|" \
                        "(inches)|(inch)")

for ind, item in data.items():
    new_ingredients = []
    if type(item['ingredients']) == np.float64:
        data = data.drop(ind, axis=1)
        print(item['ingredients'])
    else:
        for ingredient in item['ingredients']:
            new_ingredient = punc_re.sub("", ingredient)
            new_ingredient = num_re.sub("", new_ingredient)
            new_ingredient = measure_re.sub("", new_ingredient)
            new_ingredient = new_ingredient.lower()
            new_ingredients += [new_ingredient]
        data.at["ingredients", ind] = new_ingredients

# %%
data
# Out:
#                                 p3pKOD6jIHEcjf20CCXohP8uqkG5dGi  \
# instructions  Toss ingredients lightly and spoon into a butt...
# ingredients   [ celery finely chopped,  small green pepper f...
#
#                                 S7aeOIrsrgT0jLP32jKGg4j.o9zi2DO  \
# instructions  Watch how to make this recipe.\nSprinkle the s...
# ingredients   [  skirt steak cut into  dice, kosher salt and...
#
#                                 o9MItV9txfoPsUQ4v8b0vh1.VdjwfsK  \
# instructions  In a large saucepan, let the beans soak in eno...
# ingredients   [   dried black beans picked over and rinsed, ...
#
#                                 5l1yTSYFifF/M2dfbD6DX28WWQpLWNK  \
# instructions  Watch how to make this recipe.\nPreheat the ov...
# ingredients   [   ground chuck, one tomato sauce,  salt, fre...
#
#                                 kRBQSWtqYWqtkb34FGeenBSbC32gIdO  \
# instructions  Special equipment: sushi mat\nCook the brown r...
# ingredients   [ rice brown mediumgrain cooked, quinoa, sweet...
#
#                                 PmoGGX9RC5zbMJXtZH1SKzWKLFX4Aii  \
# instructions  Heat a large nonstick skillet over medium-high...
# ingredients   [ extravirgin olive oil,  baby italian eggplan...
#
#                                 g2RYP1spIUlAYsytDMsdfLNQEOnLUrO  \
# instructions  Sprinkle the saffron into 1/4 cup hot water; l...
# ingredients   [ lightly crumbled saffron threads,  sugar, ko...
#
#                                 94NWE4F4C5NzgH0zYqSdmPM/G55BjKO  \
# instructions  If using top-sliced buns, spread softened butt...
# ingredients   [ top hotdog buns or fashion your own top buns...
#
#                                 HdIbPB/8cgk17hAzbc2jUN4VBn//QKS  \
# instructions  Cut around the stems of the peppers (reserving...
# ingredients   [ green or red bell peppers,  olive oil,  onio...
#
#                                 mC7Nb4F2S.DMCjZ39kzS/ak9GqEp4iO  ...  \
# instructions  Preheat the oven to 450 degrees F. Put the cau...  ...
# ingredients   [ medium cauliflower about   cut into bitesize...  ...
#
#                                 CUZuiIs2F5A4u4EzEXB/yHN38So5CRy  \
# instructions  Fill a glass or cocktail shaker with some ice....
# ingredients   [ice,  jalapeno seeded  by  piece, fresh lime ...
#
#                                 08JThnwO3qzkhSKVuef6Ehg.HVPXt7C  \
# instructions  Watch how to make this recipe.\nHeat a heavy m...
# ingredients   [ butter,  sugar,  ground cinnamon,  large app...
#
#                                 0jaoQnb1iG0bnScGJOt/zmAl6lsOh6y  \
# instructions  Preheat the oven to 250 degrees F\nIn a small ...
# ingredients   [  coconut milk,  short stalk lemon grass fine...
#
#                                 6Qp4fKIuJAkrukUvmccA8qWrezzLwFq  \
# instructions  Bring a small saucepan of water to a boil. Sep...
# ingredients   [ large  garlic,  cutup chicken about  , salt ...
#
#                                 xwEq9YYRt37I/LTqQUWvAi1uSusxhDm  \
# instructions  Grease 8 cream horn metal cones. Cut the puff ...
# ingredients   [ sheet frozen puff pastry thawed,  egg,  wate...
#
#                                 4bfMWxlbKhx/McJq/89k0SBdw.VvAzW  \
# instructions  Watch how to make this recipe.\nPreheat a gril...
# ingredients   [ ears fresh corn,   belgian endive,   olive o...
#
#                                 T8lWBA1fcVdjxhMSWuoAbGoy5Lj.A8m  \
# instructions  Preheat the broiler. Cut the tomatoes in 1/2 c...
# ingredients   [ large plum tomatoes, salt and sugar,    zucc...
#
#                                 f/coffo2TMs2J2gq5nTOUIqH2TRAkui  \
# instructions  Heat the oil and butter in a large skillet ove...
# ingredients   [  olive oil,   unsalted butter,  medium clove...
#
#                                 q3aDJc4zoEF5QT4e7Mn.ieQwV.DyHwS  \
# instructions  Preheat oven to 350 degrees. On the top half o...
# ingredients   [  butter,   bittersweet chocolate,  whole egg...
#
#                                 7cXA77UpdDtIfBug2v6lEVIuV3Zcvhm
# instructions  Watch how to make this recipe.\nIn a medium sa...
# ingredients   [  restaurantstyle condensed crab bisque recom...
#
# [2 rows x 59628 columns]

# %%
data.loc['ingredients'][0]
# Out:
# C:\Users\sayan\AppData\Local\Temp\ipykernel_9360\3221995973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data.loc['ingredients'][0]
# [' celery finely chopped',
#  ' small green pepper finely chopped',
#  ' finely  green onions',
#  ' chopped parsley',
#  ' crabmeat',
#  '   coarsely crushed cracker crumbs',
#  ' salt',
#  '  dry mustard',
#  'dash hot sauce',
#  ' heavy cream',
#  ' melted butter']

# %% [markdown]
# Now we just have the ingredients in the

# %%
dict_of_words = {}

for ingredients in data.loc['ingredients',:]:
    for ingredient in ingredients:
        for word in ingredient.split():
            word = word.rstrip(",.")
            if not word in dict_of_words.keys():
                dict_of_words[word] = 1
            else:
                dict_of_words[word] += 1

# %%
df_words = pd.DataFrame.from_dict(dict_of_words, "index", columns=["count"])
df_words = df_words.sort_values('count', ascending=False)

# %%
sns.distplot(np.log(df_words.values), kde=False)

# %%
top_words = (df_words[0:2010].index.values)
top_words
# Out:
# array(['and', 'chopped', 'salt', ..., 'flatleafed', 'prefer', 'shaken'],
#       dtype=object)

# %%
zero_data = np.zeros(shape=(len(data.T), len(list(top_words))))
final_data = pd.DataFrame(zero_data, columns=list(top_words))

# %%
top_words_set = set(top_words)
i = 0
for ingredients in data.loc['ingredients',:]:
    bigset = set()
    for ingredient in ingredients:
        bigset.update(ingredient.split())
    for ingredient in top_words_set.intersection(bigset):
        final_data.loc[i,ingredient] = 1
    if (i % 1000 == 0):
        print(bigset)
    i += 1
# Out:
# {'crushed', 'crumbs', 'mustard', 'small', 'melted', 'sauce', 'green', 'crabmeat', 'salt', 'parsley', 'cracker', 'hot', 'heavy', 'onions', 'butter', 'celery', 'finely', 'chopped', 'dry', 'coarsely', 'pepper', 'cream', 'dash'}
# {'yellow', 'cloves', 'tomatoes', 'pois', 'grated', 'and', 'juices', 'or', 'basil', 'freshly', 'garlic', 'frozen', 'plum', 'oil', 'to', 'each', 'cheese', 'carrots', 'rotelle', 'taste', 'seeded', 'minced', 'salt', 'including', 'parsley', 'cooking', 'chicken', 'heavy', 'squash', 'olive', 'parmesan', 'reserve', 'thinly', 'liquid', 'pasta', 'broccoli', 'fresh', 'stock', 'petits', 'diced', 'pepper', 'cream', 'penne', 'florets'}
# {'rubbed', 'fingers', 'for', 'wedges', 'your', 'falafel', 'of', 'cucumber', 'extravirgin', 'dried', 'mix', 'grated', 'feta', 'half', 'and', 'wine', 'red', 'vegetable', 'oil', 'peppers', 'cheese', 'lemon', 'frying', 'leaves', 'a', 'mint', 'salt', 'parsley', 'between', 'kosher', 'juice', 'roasted', 'parmesan', 'crumbled', 'olive', 'finely', 'vinegar', 'chopped', 'tahini', 'about', 'serving'}
# {'cloves', 'quartered', 'wing', 'with', 'bone', 'thighs', 'cilantro', 'black', 'bay', 'garlic', 'bunch', 'oregano', 'oil', 'frenched', 'peppercorns', 'leaves', 'white', 'large', 'salt', 'on', 'parsley', 'chicken', 'roughly', 'cut', 'vinegar', 'onion', 'shallots', 'picked', 'chopped', 'dry', 'boneless', 'into', 'skin', 'salad', 'dice', 'legs', 'breasts'}
# {'plating', 'apple', 'for', 'optional', 'black', 'cored', 'grated', 'freshly', 'and', 'lima', 'sour', 'oil', 'carrot', 'pitted', 'fully', 'salt', 'chicken', 'butter', 'olive', 'parmesan', 'celery', 'crumbled', 'bacon', 'onion', 'cooked', 'beans', 'peeled', 'pepper', 'diced', 'ground', 'thawed', 'cream', 'broth'}
# {'cracked', 'black', 'extravirgin', 'sake', 'freshly', 'or', 'wine', 'red', 'japanese', 'steak', 'sauce', 'rice', 'oil', 'peppercorns', 'salt', 'cumin', 'juice', 'soy', 'onions', 'olive', 'lime', 'vinegar', 'dry', 'sherry', 'coarsely', 'seeds', 'fresh', 'sirloin', 'medium', 'pepper', 'ground', 'coriander'}
# {'size', 'edible', 'matchstick', 'cranberries', 'piece', 'segmented', 'dried', 'lettuce', 'feta', 'halved', 'nicoise', 'small', 'seedless', 'citruscumin', 'red', 'handful', 'cheese', 'toasted', 'sunflower', 'pitted', 'watermelon', 'butter', 'cut', 'crumbled', 'jicama', 'wedge', 'pieces', 'oranges', 'vinaigrette', 'into', 'flowers', 'peeled', 'seeds', 'olives', 'batons'}
# {'cloves', 'for', 'walnuts', 'truffle', 'plus', 'black', 'unpeeled', 'extravirgin', 'smith', 'and', 'freshly', 'small', 'apples', 'garlic', 'oil', 'very', 'grapeseed', 'green', 'lemon', 'toasted', 'more', 'large', 'salt', 'julienned', 'parsley', 'kosher', 'juice', 'cabbage', 'olive', 'sugar', 'drizzling', 'thinly', 'granny', 'chopped', 'fresh', 'about', 'pepper', 'ground'}
# set()
# {'cloves', 'turmeric', 'cinnamon', 'brown', 'cilantro', 'shredded', 'of', 'tomatoes', 'black', 'rotisserie', 'freshly', 'and', 'halved', 'or', 'wine', 'garlic', 'red', 'rice', 'oil', 'green', 'lemon', 'leaves', 'white', 'rinsed', 'pitted', 'minced', 'chickpeas', 'eggplant', 'such', 'salt', 'cutlets', 'chicken', 'kosher', 'olive', 'cut', 'ginger', 'vinegar', 'as', 'onion', 'chopped', 'cooked', 'zest', 'into', 'drained', 'grape', 'fresh', 'leftover', 'pepper', 'about', 'ground', 'cayenne', 'olives', 'cubes'}
# {'pacific', 'eggs', 'nielsenmassey', 'for', 'ied', 'marzipan', 'with', 'vanilla', 'brandy', 'plus', 'bean', 'room', 'optional', 'pure', 'cake', 'grated', 'cored', 'and', 'pan', 'sifted', 'paste', 'pear', 'light', 'flour', 'recommended', 'puree', 'preserves', 'ripe', 'corn', 'guittard', 'heated', "confectioners'", 'temperature', 'more', 'dark', 'leaves', 'syrup', 'unsalted', 'butter', 'follows', 'sugar', 'royal', 'ginger', 'garnish', 'glaze', 'divided', 'strained', 'pears', 'peeled', 'chocolate', 'recipe'}
# {'cinnamon', 'for', 'with', 'see', 'plus', 'room', 'note', "cook's", 'grated', 'egg', "confectioners'", 'lemon', 'temperature', 'more', 'large', 'rolling', 'sugar', 'please', 'finely', 'almonds', 'zest', 'skin', 'about', 'whites', 'ground'}
# {'cloves', 'crushed', 'wedges', 'crumbs', 'mussels', 'and', 'or', 'wine', 'garlic', 'oil', 'to', 'lemon', 'taste', 'white', 'salt', 'parsley', 'plain', 'olive', 'garnish', 'bread', 'dry', 'chopped', 'fresh', 'pepper', 'prosciutto'}
# {'apple', 'superfine', 'freshly', 'cracked', 'salt', 'grape', 'pints', 'to', 'juice', 'heavy', 'pepper', 'sugar', 'buttermilk', 'cream', 'and', 'raspberries', 'or'}
# {'cloves', 'grill', 'for', 'brown', 'cinnamon', 'juiced', 'nutmeg', 'plus', 'black', 'and', 'freshly', 'grates', 'garlic', 'bunch', 'allspice', 'scallions', 'oil', 'sauce', 'habanero', 'thyme', 'more', 'packed', 'leaves', 'large', 'salt', 'chicken', 'kosher', 'soy', 'olive', 'sugar', 'lime', 'boneless', 'chopped', 'chile', 'greasing', 'fresh', 'pepper', 'ground', 'skinless', 'breasts'}
# {'cinnamon', 'shredded', 'crumbs', 'coconut', 'and', 'nuts', 'toasted', 'dark', 'powder', 'chili', 'shelled', 'pistachio', 'heavy', 'extrafine', 'cocoa', 'chopped', 'cookie', 'chocolate', 'pepper', 'ground', 'cayenne', 'cream'}
# {'cinnamon', 'apple', 'sea', 'cider', 'lady', 'goji', 'soften', 'dried', 'and', 'bananas', 'or', 'berries', 'raw', 'apples', 'whole', 'ripe', 'to', 'chipotle', 'p', 'lemon', 'pitted', 'salt', 'soaked', 'grain', 'almond', 'butter', 'juice', 'vinegar', 'cherries', 'bread', 'chopped', 'pink', 'medium', 'fresh', 'pepper', 'fuji', 'ground', 'cayenne', 'halved', 'glutenfree'}
# {'flour', 'water', 'such', 'salt', 'vegetable', 'unsalted', 'cold', 'crisco', 'allpurpose', 'very', 'butter', 'kosher', 'ice', 'sugar', 'as', 'shortening', 'sticks'}
# {'plumstyle', 'salt', 'jalapeno', 'c', 'juice', 'tomatoes', 'lemon', 'peppers', 'bottled', 'vinegar', 'onion', 'or'}
# {'plus', 'black', 'if', 'pure', 'pork', 'mustard', 'desired', 'small', 'to', 'more', 'white', 'pea', 'syrup', 'salt', 'onion', 'chopped', 'dry', 'coarsely', 'beans', 'maple', 'pepper', 'ground'}
# {'tortilla', 'sea', 'cilantro', 'avocado', 'fried', 'and', 'freshly', 'or', 'flour', 'sour', 'red', 'chips', 'bag', 'oil', 'haas', 'corn', 'pitted', 'salt', 'parsley', 'juice', 'roasted', 'olive', 'finely', 'lime', 'onion', 'scallops', 'chopped', 'coarsely', 'kernels', 'peeled', 'fresh', 'pepper', 'diced', 'ground', 'baked', 'cream'}
# {'prebaked', 'eggs', 'shells', 'large', 'yolks', 'tartlet', 'granulated', 'egg', 'passion', 'juice', 'sugar', 'fruit', 'recipe', 'follows', 'whites'}
# {'flour', 'for', 'available', 'water', 'coarse', 'salt', 'coating', 'warm', 'oil', 'allpurpose', 'fresh', 'plus', 'if', 'yeast', 'otherwise', 'extravirgin', 'olive', 'bowl', 'pans', 'more'}
# {'for', 'ground', 'the', 'tomatoes', 'black', 'grated', 'pan', 'freshly', 'and', 'lettuce', 'oil', 'sauce', 'mayonnaise', 'egg', 'swiss', 'cheese', 'toasted', 'large', 'powder', 'chili', 'salt', 'seasoned', 'hot', 'buns', 'onion', 'ed', 'breadcrumbs', 'drained', 'topping', 'beans', 'burger', 'pepper', 'la'}
# {'ham', 'brown', 'dry', 'seedless', 'spicy', 'preferably', 'rootbeer', 'spiral', 'to', 'hot', 'kumquats', 'green', 'quality', 'cut', 'sugar', 'mustard', 'grapes', 'dark', 'liters', 'or'}
# set()
# {'crushed', 'quartered', 'wedges', 'bitesized', 'squeezed', 'limes', 'chunks', 'freshly', 'recommended', 'red', 'soda', 'ruby', 'each', 'squirt', 'lemon', 'grapefruit', 'pineapple', 'watermelon', 'juice', 'cut', 'lime', 'oranges', 'orange', 'into', 'fresh', 'ice'}
# {'cloves', 'spicy', 'juiced', 'dijon', 'kale', 'croutons', 'black', 'capers', 'torn', 'mustard', 'you', 'freshly', 'and', 'small', 'garlic', 'sesame', 'oil', 'to', 'mayonnaise', 'how', 'like', 'p', 'it', 'lemon', 'toasted', 'bunches', 'salt', 'on', 'kosher', 'stemmed', 'parmesan', 'pieces', 'into', 'drained', 'depending', 'about', 'pepper', 'shaved', 'ground', 'cayenne', 'bitesize', 'tablespoon'}
# {'cinnamon', 'for', 'brown', 'vanilla', 'plus', 'smith', 'extract', 'apples', 'flour', 'softened', 'p', 'lard', 'more', 'sprinkling', 'salt', 'dusting', 'unsalted', 'butter', 'sugar', 'cut', 'pieces', 'water', 'granny', 'into', 'granulated', 'allpurpose', 'ground'}
# {'small', 'white', 'quartered', 'cloves', 'potato', 'chopped', 'red', 'garlic', 'minced', 'freshly', 'salt', 'ground', 'oil', 'to', 'pepper', 'black', 'olive', 'rosemary', 'and', 'leaves'}
# {'in', 'brown', 'light', 'pods', 'peas', 'asian', 'rice', 'oil', 'to', 'sauce', 'green', 'packed', 'pea', 'snap', 'shelled', 'soy', 'sugar', 'vinegar', 'shoots', 'seeds', 'fresh', 'about', 'sesame', 'snow'}
# {'smooth', 'in', 'peanut', 'cider', 'shredded', 'tamari', 'eyeball', 'bean', 'variety', 'mix', 'angle', 'and', 'or', 'produce', 'wine', 'softened', 'seconds', 'rice', 'oil', 'sauce', 'scallions', 'it', 'carrot', 'high', 'any', 'dark', 'spaghetti', 'pea', 'sprouts', 'available', 'an', 'on', 'microwave', 'hot', 'butter', 'soy', 'cabbage', 'vinegar', 'chopped', 'department', 'shoots', 'seeds', 'rounded', 'sesame'}
# {'brown', 'with', 'bone', 'nutmeg', 'black', 'pork', 'grated', 'freshly', 'light', 'red', 'back', 'sage', 'thyme', 'leaves', 'salt', 'kosher', 'rosemary', 'sugar', 'finely', 'pieces', 'chopped', 'into', 'fat', 'flakes', 'fresh', 'butt', 'diced', 'pepper', 'ground', 'cayenne'}
# {'concord', 'currant', 'grape', 'juice', 'black', 'sugar'}
# {'oranges', 'vodka', 'club', 'l', 'honey', 'salt', 'orange', 'soda', 'campari', 'ml', 'p', 'juice', 'of', 'sugar', "confectioners'", 'cayenne'}
# {'for', 'syrup', 'zest', 'silver', 'orange', 'simple', 'cold', 'fresh', 'juice', 'optional', 'tequila', 'beer', 'ginger', 'lime', 'wedge', 'garnish'}
# {'grenadine', 'rum', 'proof', 'light'}
# {'cloves', 'turmeric', 'removed', 'black', 'and', 'freshly', 'garlic', 'wine', 'shiitake', 'rice', 'white', 'longgrain', 'minced', 'cremini', 'salt', 'parsley', 'mushrooms', 'chicken', 'butter', 'roughly', 'onions', 'finely', 'chopped', 'stems', 'medium', 'fresh', 'stock', 'pepper', 'ground'}
# {'cloves', 'brown', 'golden', 'hawaiianstyle', 'of', 'black', 'piece', 'pork', 'freshly', 'and', 'garlic', 'red', 'rice', 'oil', 'sauce', 'to', 'very', 'tenderloin', 'green', 'mini', 'packed', 'large', 'sweet', 'minced', 'salt', 'seasoned', 'kosher', 'juice', 'cabbage', 'onions', 'soy', 'sugar', 'rolls', 'ginger', 'vinegar', 'trimmed', 'thinly', 'horizontally', 'zest', 'orange', 'one', 'arrowroot', 'peeled', 'fresh', 'about', 'pepper', 'ground', 'sesame', 'halved'}
# {'quartered', 'ellini', 'with', 'endive', 'prepared', 'fillets', 'extravirgin', 'torn', 'and', 'freshly', 'small', 'garlic', 'red', 'handful', 'oil', 'peppers', 'clove', 'sprig', 'rinsed', 'salt', 'parsley', 'chicken', 'lengthwise', 'kosher', 'roughly', 'olive', 'sugar', 'roasted', 'lowsodium', 'rosemary', 'onion', 'thinly', 'chopped', 'drained', 'skin', 'beans', 'halibut', 'fresh', 'pepper', 'ground', 'broth'}
# {'walnuts', 'plus', 'extravirgin', 'grated', 'bay', 'basil', 'oil', 'leaves', 'salt', 'linguine', 'parsley', 'flatleaf', 'mushrooms', 'kosher', 'parmesan', 'olive', 'scallops', 'chopped', 'zucchini', 'fresh', 'cleaned'}
# set()
# {'black', 'extravirgin', 'freshly', 'and', 'softened', 'oil', 'like', 'parsnips', 'mixed', 'herbs', 'salt', 'unsalted', 'parsley', 'kosher', 'butter', 'olive', 'chopped', 'into', 'circles', 'peeled', 'chives', 'fresh', 'pepper', 'ground', 'chervil'}
# {'cloves', 'cinnamon', 'black', 'pork', 'dried', 'freshly', 'bay', 'and', 'sticks', 'roast', 'dr', 'recommended', 'soda', 'oil', 'loin', 'halves', 'la', 'pitted', 'peppery', 'salt', 'onions', 'prunes', 'apricot', 'leaf', 'medium', 'pepper', 'ground'}
# {'ears', 'ground', 'sweet', 'freshly', 'from', 'coarse', 'into', 'salt', 'lardons', 'kernels', 'fresh', 'about', 'corn', 'kosher', 'black', 'cut', 'scraped', 'bacon', 'pepper', 'and'}
# {'crushed', 'roots', 'cilantro', 'straw', 'the', 'of', 'smashed', 'and', 'bay', 'or', 'garlic', 'deveined', 'red', 'enoki', 'bunch', 'vegetable', 'shrimp', 'oil', 'to', 'domestic', 'garni', 'clove', 'mushroom', 'packed', 'leaves', 'a', 'minced', 'chili', 'salt', 'including', 'rounds', 'mushrooms', 'juice', 'cut', 'lime', 'bouquet', 'pieces', 'trimmed', 'ed', 'shallots', 'water', 'chopped', 'stems', 'caps', 'into', 'coarsely', 'peeled', 'leaf', 'fresh', 'pepper', 'asparagus'}
# {'yellow', 'sundried', 'shredded', 'artichoke', 'blanched', 'farfalle', 'tomatoes', 'feta', 'tomato', 'and', 'basil', 'fin', 'garlic', 'wine', 'plum', 'oil', 'to', 'center', 'lemon', 'taste', 'heart', 'minced', 'salt', 'heavy', 'olive', 'cut', 'tuna', 'parmesan', 'cooked', 'pasta', 'broccoli', 'peeled', 'fresh', 'chablis', 'pepper', 'diced', 'cream', 'florets'}
# {'reserved', 'cinnamon', 'cherries', 'sour', 'cornstarch', 'cherry', 'stick', 'frozen', 'drained', 'ruby', 'vanilla', 'juice', 'bean', 'thawed', 'port', 'ricotta'}
# {'for', 'baking', 'the', 'and', 'or', 'vegetable', 'scallions', 'to', 'oil', 'egg', 'green', 'frying', 'russet', 'taste', 'yukon', 'large', 'salt', 'including', 'part', 'beaten', 'onion', 'chopped', 'potatoes', 'gold', 'medium', 'pepper'}
# {'cloves', 'cinnamon', 'for', 'quartered', 'yogurt', 'apricots', 'lowfat', 'percent', 'of', 'plus', 'smashed', 'optional', 'pitas', 'dried', 'tomato', 'and', 'or', 'small', 'garlic', 'red', 'masala', 'wholewheat', 'color', 'sauce', 'p', 'any', 'more', 'rinsed', 'large', 'chickpeas', 'greek', 'salt', 'nosaltadded', 'parsley', 'chicken', 'kosher', 'thinly', 'boneless', 'chopped', 'drained', 'topping', 'flakes', 'garam', 'fresh', 'pepper', 'bell', 'ground', 'halved', 'skinless', 'breasts'}
# {'dill', 'black', 'paste', 'tomato', 'freshly', 'garlic', 'oil', 'rice', 'lemon', 'leaves', 'white', 'large', 'jar', 'salt', 'kosher', 'juice', 'onions', 'olive', 'finely', 'chopped', 'grape', 'pepper', 'ground'}
# {'milk', 'banana', 'blueberries', 'grape', 'frozen', 'lowfat', 'pomegranate', 'strawberries', 'juice', 'soy', 'plain', 'peaches', 'acai', 'or'}
# {'crushed', 'cloves', 'for', 'sausage', 'with', 'ground', 'cold', 'attachments', 'horn', 'of', 'plus', 'ice', 'extravirgin', 'half', 'pork', 'grated', 'tomato', 'bay', 'and', 'paste', 'chunks', 'budiced', 'equipment', 'stand', 'garlic', 'wine', 'red', 'sage', 'parmigianoreggiano', 'puree', 'good', 'oil', 'mixer', 'p', 'clove', 'more', 'meat', 'leaves', 'white', 'a', 'large', 'amount', 'minced', 'special', 'salt', 'grinder', 'kosher', 'italian', 'follows', 'olive', 'cut', 'celery', 'mascarpone', 'casing', 'finely', 'onion', 'fennel', 'milk', 'rib', 'water', 'chopped', 'seed', 'into', 'peeled', 'flakes', 'leaf', 'fat', 'fresh', 'pepper', 'polenta', 'recipe', 'diced', 'cayenne', 'coriander', 'hog', 'serving', 'shoulder'}
# {'for', 'dill', 'juiced', 'cold', 'bufennel', 'removed', 'black', 'segmented', 'extravirgin', 'core', 'and', 'freshly', 'or', 'small', 'garlic', 'watercress', 'minutes', 'oil', 'lemon', 'clove', 'toasted', 'large', 'minced', 'salt', 'soaked', 'olive', 'fronds', 'fennel', 'oranges', 'thinly', 'water', 'chopped', 'seed', 'shallot', 'orange', 'drained', 'coarsely', 'zested', 'shaved', 'pepper', 'ground', 'coriander'}
# {'with', 'shredded', 'tomatoes', 'pure', 'and', 'nostick', 'frozen', 'wesson®', 'pam®', 'vegetable', 'oz', 'each', 'oil', 'egg', 'green', 'peppers', 'cheese', 'beaters®', "o'brien", 'cooking', 'jack', 'chilies', 'original', 'onions', 'spray', 'co', 'rotel®', 'carton', 'potatoes', 'fat', 'diced', 'undrained', 'reduced'}
# {'cloves', 'sausage', 'for', 'from', 'removed', 'plus', 'warm', 'and', 'freshly', 'garlic', 'red', 'sage', 'to', 'egg', 'carrot', 'casings', 'more', 'leaves', 'large', 'slightly', 'salt', 'unsalted', 'chicken', 'hot', 'italian', 'butter', 'cut', 'celery', 'finely', 'stalks', 'onion', 'beaten', 'chopped', 'bread', 'into', 'greasing', 'dish', 'fresh', 'pepper', 'diced', 'stock', 'ground', 'dice', 'country', 'stale'}
# {'cinnamon', 'eggs', 'for', 'brown', 'tapioca', 'baking', 'vanilla', 'plus', 'room', 'additional', 'xanthan', 'at', 'pan', 'pure', 'light', 'sticks', 'extract', 'sifted', 'gum', 'flour', 'whole', 'soda', 'rice', "confectioners'", 'starch', 'temperature', 'packed', 'white', 'large', 'potato', 'powder', 'salt', 'unsalted', 'butter', 'sugar', 'milk', 'pe', 'chopped', 'topping', 'greasing', 'firmly', 'buttermilk', 'ground'}
# {'cloves', 'pine', 'jumbo', 'romano', 'grated', 'basil', 'garlic', 'nuts', 'softened', 'oil', 'shrimp', 'toasted', 'leaves', 'salt', 'butter', 'olive', 'parmesan', 'divided', 'fresh', 'pecorino', 'pignoli'}
# {'for', 'brown', 'matchsticks', 'shredded', 'limes', 'dijon', 'of', 'plus', 'bean', 'coconut', 'mustard', 'paste', 'grated', 'and', 'bok', 'udon', 'flour', 'wine', 'red', 'rice', 'to', 'oil', 'sauce', 'mayonnaise', 'scallions', 'unsweetened', 'baby', 'frying', 'bunches', 'carrot', 'taste', 'choy', 'la', 'sprouts', 'curry', 'powder', 'chili', 'salt', 'hoisin', 'chicken', 'juice', 'cabbage', 'sugar', 'cut', 'ginger', 'noodles', 'vinegar', 'pieces', 'onion', 'milk', 'boneless', 'semolina', 'chopped', 'cooked', 'cornstarch', 'into', 'allpurpose', 'fresh', 'pepper', 'buttermilk', 'ground', 'breasts'}
# {'cracked', 'pearl', 'dijon', 'currants', 'cucumber', 'black', 'dried', 'mustard', 'tomato', 'vineripened', 'freshly', 'and', 'red', 'arugula', 'oil', 'baby', 'lemon', 'seeded', 'salt', 'kosher', 'juice', 'olive', 'couscous', 'onion', 'israeli', 'flakes', 'fresh', 'pepper', 'diced', 'hothouse', 'bell', 'curly'}

# %%
pca = sklearn.decomposition.PCA(n_components=2)
pcaed = pca.fit_transform(final_data)

# %%
plt.scatter(pcaed[:, 0], pcaed[:, 1], s=0.01)

# %%
embedding = umap.UMAP(n_neighbors=100,
                      min_dist=0.3,
                      metric='correlation').fit_transform(final_data)

# %%
pickle.dump(final_data, open( "final_data.p", "wb" ))
pickle.dump(embedding, open( "embedding.p", "wb" ))
